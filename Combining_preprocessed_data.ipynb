# %%
import pandas as pd
import numpy as np

# %%
df_tmdb = pd.read_csv('tmdb_preprocessed_data.csv')
df_2018 = pd.read_csv('2018_wiki_preprocessed_data.csv')
df_2019 = pd.read_csv('2019_wiki_preprocessed_data.csv')

# %%
df_final = pd.concat([df_tmdb, df_2018, df_2019]).reset_index()

# %%
df_final.drop(columns='index', inplace=True)

# %%
df_final
# Out:
#             director_name     actor_1_name         actor_2_name  \
# 0            JamesCameron       CCHPounder       JoelDavidMoore
# 1           GoreVerbinski       JohnnyDepp         OrlandoBloom
# 2               SamMendes   ChristophWaltz          RoryKinnear
# 3        ChristopherNolan         TomHardy        ChristianBale
# 4              DougWalker       DougWalker            RobWalker
# ...                   ...              ...                  ...
# 5414  NickBruno,TroyQuane        WillSmith           TomHolland
# 5415          GretaGerwig     SaoirseRonan           EmmaWatson
# 5416            SamMendes     GeorgeMacKay  Dean-CharlesChapman
# 5417  DestinDanielCretton  MichaelB.Jordan            JamieFoxx
# 5418       ChinonyeChukwu     AlfreWoodard        WendellPierce
#
#              actor_3_name                                    genres  \
# 0                WesStudi           action adventure fantasy sci-fi
# 1           JackDavenport                  action adventure fantasy
# 2         StephanieSigman                 action adventure thriller
# 3     JosephGordon-Levitt                           action thriller
# 4     JosephGordon-Levitt                               documentary
# ...                   ...                                       ...
# 5414         RashidaJones  animation action adventure comedy family
# 5415         FlorencePugh                             drama romance
# 5416           MarkStrong                 war drama action thriller
# 5417           BrieLarson                       drama crime history
# 5418           AldisHodge                                     drama
#
#                                             movie_title  \
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5414                                  Spies in Disguise
# 5415                                       Little Women
# 5416                                               1917
# 5417                                         Just Mercy
# 5418                                           Clemency
#
#                                                    comb
# 0     CCHPounder JoelDavidMoore WesStudi JamesCamero...
# 1     JohnnyDepp OrlandoBloom JackDavenport GoreVerb...
# 2     ChristophWaltz RoryKinnear StephanieSigman Sam...
# 3     TomHardy ChristianBale JosephGordon-Levitt Chr...
# 4     DougWalker RobWalker JosephGordon-Levitt DougW...
# ...                                                 ...
# 5414  WillSmith TomHolland RashidaJones NickBruno,Tr...
# 5415  SaoirseRonan EmmaWatson FlorencePugh GretaGerw...
# 5416  GeorgeMacKay Dean-CharlesChapman MarkStrong Sa...
# 5417  MichaelB.Jordan JamieFoxx BrieLarson DestinDan...
# 5418  AlfreWoodard WendellPierce AldisHodge Chinonye...
#
# [5419 rows x 7 columns]

# %%
df_final.to_csv("final_preprocessed_data.csv")
